# %%
pwd()
# Out:
# '/Users/cindyhu/Documents/Courses/CS171/teamAqua/ucmr-3-occurrence-data'

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('ucmrByCounty_final.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0  COUNTY  AnalyticalResultValue.count.1,1-dichloroethane  \
# 0           0    1001                                            59.0
# 1           1    1003                                           122.0
# 2           2    1005                                            14.0
# 3           3    1007                                             8.0
# 4           4    1009                                            80.0
#
#    AnalyticalResultValue.count.1,2,3-trichloropropane  \
# 0                                               59.0
# 1                                              122.0
# 2                                               14.0
# 3                                                8.0
# 4                                               80.0
#
#    AnalyticalResultValue.count.1,3-butadiene  \
# 0                                       59.0
# 1                                      122.0
# 2                                       14.0
# ...

# %%
df2 = df.drop(['COUNTY','countyname'], 1).groupby(['state']).mean()

# %%
df2.to_csv('ucmrByState.csv')

# %%
df2.shape
# Out:
# (52, 186)

# %%
fips = pd.read_csv('state_fips.csv')[['state','name']]

# %%
fips.head()
# Out:
#   state            name
# 0    AK          Alaska
# 1    AL         Alabama
# 2    AR        Arkansas
# 3    AS  American Samoa
# 4    AZ         Arizona

# %%
df2 = pd.read_csv('ucmrByState.csv')

# %%
df2 = pd.merge(df2, fips, on='state')

# %%
df2.head()
# Out:
#   state  Unnamed: 0  AnalyticalResultValue.count.1,1-dichloroethane  \
# 0    AK        63.5                                       17.000000
# 1    AL        30.0                                       54.620690
# 2    AR       104.5                                       13.363636
# 3    AZ        73.0                                      689.000000
# 4    CA       155.0                                     1195.979592
#
#    AnalyticalResultValue.count.1,2,3-trichloropropane  \
# 0                                          17.000000
# 1                                          54.620690
# 2                                          13.363636
# 3                                         689.000000
# 4                                        1195.979592
#
#    AnalyticalResultValue.count.1,3-butadiene  \
# 0                                  17.000000
# 1                                  54.620690
# 2                                  13.363636
# 3                                 689.000000
# ...

# %%
df2.to_csv('ucmrByState_final.csv')
